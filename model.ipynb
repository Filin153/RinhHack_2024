# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.covariance import EllipticEnvelope

# %% [markdown]
# # Загрузка очищенных данных

# %%
df = pd.read_csv("normal.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53079 entries, 0 to 53078
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       53079 non-null  int64
#  1   transaction_id   53079 non-null  int64
#  2   ip               53079 non-null  int64
#  3   device_id        53079 non-null  float64
#  4   device_type      53079 non-null  object
#  5   tran_code        53079 non-null  int64
#  6   mcc              53079 non-null  int64
#  7   client_id        53079 non-null  int64
#  8   card_type        53079 non-null  object
#  9   pin_inc_count    53079 non-null  int64
#  10  card_status      53079 non-null  int64
#  11  expiration_date  53079 non-null  object
#  12  datetime         53079 non-null  object
#  13  sum              53079 non-null  float64
#  14  oper_type        53079 non-null  object
#  15  balance          53079 non-null  float64
# dtypes: float64(3), int64(8), object(5)
# memory usage: 6.5+ MB

# %% [markdown]
# # Предобработка данных

# %%
to_drop = ['Unnamed: 0', 'expiration_date', 'datetime']
need = []

for col in df.columns:
    if col not in to_drop:
        need.append(col)

df = df[need]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53079 entries, 0 to 53078
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  53079 non-null  int64
#  1   ip              53079 non-null  int64
#  2   device_id       53079 non-null  float64
#  3   device_type     53079 non-null  object
#  4   tran_code       53079 non-null  int64
#  5   mcc             53079 non-null  int64
#  6   client_id       53079 non-null  int64
#  7   card_type       53079 non-null  object
#  8   pin_inc_count   53079 non-null  int64
#  9   card_status     53079 non-null  int64
#  10  sum             53079 non-null  float64
#  11  oper_type       53079 non-null  object
#  12  balance         53079 non-null  float64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 5.3+ MB

# %%
from sklearn.preprocessing import LabelEncoder

df_label = df.copy()

rare_threshold = 2500

for col in df.select_dtypes(include='object').columns:
    print(col)
    
    value_counts = df_label[col].value_counts()
    rare_values = value_counts[value_counts < rare_threshold].index
    df_label[col] = df_label[col].apply(lambda x: 'SMALL' if x in rare_values else x)
    
    label_encoder = LabelEncoder()
    df_label[col] = label_encoder.fit_transform(df_label[col])
# Out:
# device_type
# card_type
# oper_type

# %% [markdown]
# # Поиск аномалий

# %%
model_if = IsolationForest(**{'n_estimators': 50, 'max_samples': 0.1, 'contamination': 0.02, 'max_features': 1.0, 'bootstrap': False, 'n_jobs': -1, 'random_state': 100, 'warm_start': False})
model_if.fit(df_label)
# Out:
# IsolationForest(contamination=0.02, max_samples=0.1, n_estimators=50, n_jobs=-1,
#                 random_state=100)

# %%
clf = LocalOutlierFactor(n_neighbors=200, contamination=0.00013)

# %%
cov = EllipticEnvelope(random_state=100, contamination=0.00013).fit(df_label)
# Out:
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.994285590343509 > 173.978518607238584). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.620204519364705 > 171.607566523920696). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.619039537656334 > 170.812298632485380). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.018631673399113 > 172.916817013251688). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.751823146580364 > 172.503527402383696). You may want to try with a higher value of support_fraction (current value: 0.502).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.959996589585387 > 166.941417693074698). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.944564992237815 > 166.904534417542550). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.026080173007443 > 170.286126100656247). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.933172499440104 > 170.913803533348073). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.038270691342461 > 166.890960541547059). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.975117223216330 > 166.895340113714468). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.980679036053459 > 166.930349852242472). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.035496461176166 > 166.917126081384396). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.013505625903889 > 166.879543913131073). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.035313941448635 > 171.808224445669680). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.240334587213624 > 166.152309691936580). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.222897339759726 > 166.874078930354869). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.778653237531614 > 172.404493740326529). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.209420872102953 > 166.178423927317169). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.273420054551025 > 171.258507649994357). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.188237005974571 > 166.855903746709117). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.221020868982947 > 170.327869187509606). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.940097932611479 > 166.812586453290066). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.238489674500812 > 166.884180427792131). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.947457297062556 > 171.294316495516512). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.901231517257287 > 170.613566117091978). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.194870343745293 > 171.829392351170043). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.230765076415054 > 169.560256094139476). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.981359512034373 > 166.871276115213021). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.891412383997420 > 166.921214102772012). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.287089537379074 > 170.577849817618983). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.503074138394368 > 172.389919418121167). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.256883466990161 > 171.731734122837878). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.947664787651036 > 166.827978423495182). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.917728703966361 > 171.108314365058902). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.058601845262388 > 171.832087478650521). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.002442930881415 > 166.921004330227959). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.982847029765821 > 166.884373121158234). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.059629513129295 > 166.901316018340395). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.012453849607624 > 166.917649896787367). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.072051689554854 > 166.951311204009158). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.951789131626015 > 166.863479800793471). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.032622833352605 > 166.950424580838757). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.967348006906860 > 166.906130828698707). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.007659447376994 > 171.804308412387030). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.335738716322652 > 167.024604251105330). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.415677195788703 > 166.396953638805115). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.351422529997052 > 169.771464414929454). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.996601077681703 > 166.937006974886543). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.304401419011185 > 171.652517779775536). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.370269190477472 > 171.514172128334991). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.354458178149940 > 166.309496615002047). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.290455650517231 > 166.904734728582895). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.451417555839782 > 172.441784960196458). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.428547603359107 > 166.391348788985056). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.971060742661535 > 166.870390388181391). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.986417801731562 > 166.896762383704555). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.931029399746677 > 166.832750290254495). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.955035087590147 > 166.890825244005697). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.924841463947843 > 166.947155599186800). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.961599772033622 > 166.883373421280737). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.969310501073551 > 171.657060780494845). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.925786110707975 > 166.825257534216433). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.987097443120177 > 166.914443942102309). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.936213808730116 > 166.894499455451609). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.020471489833056 > 166.932551826746447). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.976670102257657 > 166.901555470661975). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.360372052542260 > 166.917195732179579). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.995012371223083 > 166.903246206559515). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.000976050904541 > 166.883766338164833). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.001528408050604 > 171.482278839313551). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.071793651681020 > 169.643104527344008). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.996081958582948 > 166.883716353571003). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.016607674321278 > 169.640059348083071). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.064469223202423 > 171.527834663401705). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.946573746615826 > 166.897825830398517). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.240177982682127 > 166.853830355586126). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.012703300633433 > 166.891977081496549). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.002993477673073 > 170.237592372579542). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.002381997164633 > 166.960520405552444). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.328490862925065 > 166.842821706110840). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.321876071753735 > 166.861147819049989). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.272234052497879 > 168.947067305707350). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.373751497491412 > 171.306760970661088). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.334108751539759 > 166.860619600755882). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.890872964973767 > 171.934789004017063). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.925092114176692 > 166.890911120046837). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.950802500815598 > 166.851798704693834). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.251998046074107 > 166.830312008518717). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.979508744204310 > 169.569954182759119). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.917961898381179 > 171.688803809113182). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.989934486913768 > 166.927969433566432). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.005503302086964 > 171.127571730693830). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.048072317448316 > 166.876592386209609). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.962121092119247 > 166.883801038411917). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.942994083565821 > 166.884977325316783). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.901039781315262 > 170.232649940626061). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.992069654959892 > 166.911387702016100). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.315701897283532 > 166.884072224470884). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.991271208894233 > 166.884965323155029). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.949548976393629 > 170.898633340514522). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.283428347926417 > 166.856076478491701). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.304704557297271 > 166.195351113944980). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.006846999927234 > 170.914099026288824). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.941071265119234 > 166.893859969846687). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.950918731015861 > 166.855849241411534). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.909994490516937 > 166.860847993230891). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.995090771444495 > 166.914904421918123). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.486430511685796 > 172.418218320898688). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.887382994612750 > 166.967346005959342). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.982087860170850 > 166.946626260268999). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.021601553626994 > 166.940700491281376). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.020444254021612 > 170.702333929409548). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.253702733722292 > 166.947683758473886). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.883520648000513 > 166.976873171450961). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.331527939494151 > 166.224499762970311). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.279829980769620 > 170.256044904368650). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.984534913515375 > 170.599159601627207). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.126415046963189 > 172.434702779725171). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.153713450720971 > 172.448070397723882). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.149270480090848 > 172.471682379821829). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.060778110388895 > 172.387390533574376). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.467588503586228 > 172.444688548271870). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.857141474586740 > 172.444284741852300). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.048126740390842 > 166.966167606096747). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.080068200383408 > 166.886363626338209). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.987692429955928 > 166.950429763413553). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.048375797581315 > 166.943609906440145). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.415600513770727 > 170.772208413236115). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.361309547450986 > 166.871183535310593). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.794483115040435 > 172.439298972786986). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.967493492963172 > 171.809034923484802). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.895553614097565 > 166.937056315684202). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.342352192762405 > 169.672144366833578). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.971651264655208 > 166.924482652877202). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.326153100359306 > 166.894008803044670). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.965511174660293 > 166.923141398940174). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.960986630878097 > 166.892782702913394). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.016659440262998 > 166.902667206311719). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.103056053738726 > 172.446748218379128). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.114555370271944 > 173.108730314070925). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.330914719261472 > 167.407527476772657). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.344800375598425 > 166.954922900357303). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.267840583413744 > 170.142481456511661). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.974790221519299 > 166.852722584190673). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.960018692988541 > 166.842686529056209). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.948897259776743 > 166.894935598274571). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.947120565796752 > 166.911044145228885). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.971300508608721 > 170.602195193964292). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.295979150727703 > 169.577296681620709). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.962687790251721 > 166.852265201138266). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.996913447349414 > 166.946351518580116). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.972216995274323 > 166.905293811052218). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.007229767325725 > 166.894311962289635). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.024879349443296 > 166.932489806936957). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.978202561435836 > 166.914399076672566). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.311815036789824 > 166.938111701994075). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.048772464676858 > 166.920828169535923). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (173.056519242477634 > 166.882742156216608). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.980645279827257 > 166.879425357121733). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.976417788998248 > 169.614249571770756). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.297533062223550 > 166.884040911948745). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.972732857982606 > 166.882354858451066). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.291444459174784 > 166.907005154971586). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.417757937692215 > 172.361922271412823). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.377581816921435 > 172.320370863338013). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.171381297351274 > 166.351110691743600). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.341609286385761 > 172.274250820643232). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.168550561645674 > 166.298051997644791). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.168239684409940 > 166.345020587579654). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.171352235059828 > 166.319760410657125). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.340679484355348 > 172.319430078080387). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.342899987561964 > 172.285916482736496). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(
# /Users/dima/PycharmProjects/RINH_2024_ZI/.venv/lib/python3.10/site-packages/sklearn/covariance/_robust_covariance.py:187: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (172.337153468361322 > 172.276401987091418). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(

# %%
df_stat = df_label.copy()

df_stat['scores_if'] = model_if.decision_function(df_label)
df_stat['scores_cov'] = cov.decision_function(df_label)
df_stat['anomaly_if'] = model_if.predict(df_label)
df_stat['anomaly_lof'] = clf.fit_predict(df_label)
df_stat['anomaly_cov'] = cov.predict(df_label)

# %%
anomaly = df_stat.loc[((df_stat['anomaly_if'] == -1) & (df_stat['scores_if'] < -0.1)) | (df_stat['anomaly_lof'] == -1) |
((df_stat['anomaly_cov'] == -1) & (df_stat['scores_cov'] <= -20))]

anomaly_index = list(anomaly.index)

# %%
res = []
for i in df.index:
    if i in anomaly_index:
        res.append(True)
    else:
        res.append(False)

# %% [markdown]
# # Обучение модели CatBoostClassifier

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report



X_train, X_test, y_train, y_test = train_test_split(df_label, res, test_size=0.2, random_state=100)

# Применение SMOTE для увеличения примеров для редкого класса
smote = SMOTE(random_state=100)
X_train, y_train = smote.fit_resample(X_train, y_train)
X_test, y_test = smote.fit_resample(X_test, y_test)


model = CatBoostClassifier(iterations=5,
                           depth=5,
                           learning_rate=0.1,
                           loss_function='Logloss',
                           verbose=True,
                           subsample=0.8,
                           colsample_bylevel=0.8,
                           l2_leaf_reg=20,
                           random_strength=0.6,
                           )


model.fit(X_train, y_train, eval_set=(X_test, y_test), verbose=True, early_stopping_rounds=10)

print(classification_report(y_test, model.predict(X_test)))
# Out:
# 0:	learn: 0.5990894	test: 0.5998234	best: 0.5998234 (0)	total: 64.8ms	remaining: 259ms
# 1:	learn: 0.5225436	test: 0.5279402	best: 0.5279402 (1)	total: 68.6ms	remaining: 103ms
# 2:	learn: 0.4597587	test: 0.4690563	best: 0.4690563 (2)	total: 71.8ms	remaining: 47.9ms
# 3:	learn: 0.4061525	test: 0.4181278	best: 0.4181278 (3)	total: 74.5ms	remaining: 18.6ms
# 4:	learn: 0.3598136	test: 0.3742210	best: 0.3742210 (4)	total: 77.2ms	remaining: 0us
#
# bestTest = 0.3742209916
# bestIteration = 4
#
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98     10595
#         True       1.00      0.96      0.98     10595
#
#     accuracy                           0.98     21190
#    macro avg       0.98      0.98      0.98     21190
# weighted avg       0.98      0.98      0.98     21190

# %% [markdown]
# ## Сохранение модели в "catboost_model.bin"

# %%
model.save_model('catboost_model.bin')

# %%
def use_model(path_to_data: str):
    df = pd.read_csv(path_to_data)
    df_label = df.copy()
    for col in df.select_dtypes(include='object').columns:
        value_counts = df_label[col].value_counts()
        rare_values = value_counts[value_counts < rare_threshold].index
        df_label[col] = df_label[col].apply(lambda x: 'SMALL' if x in rare_values else x)

        label_encoder = LabelEncoder()
        df_label[col] = label_encoder.fit_transform(df_label[col])
        
    return model.predict(df_label)

# %% [markdown]
# # Сохранение результата "preds.csv"

# %%
df['res'] = use_model("normal.csv")

anomaly = df[df['res'] == True]
anomaly_index = list(anomaly.index)

anomaly.to_csv("anomaly.csv")

res = []
for i in df.index:
    if i in anomaly_index:
        res.append('True')
    else:
        res.append('False')

with open("preds.csv", "w", encoding="utf-8") as f:
    f.write("\n".join(res))
    
print("Результат сохранен в -> preds.csv")
# Out:
# Результат сохранен в -> preds.csv
